# %% [markdown]
# <a href="https://colab.research.google.com/github/shloknair1005/Pytorch/blob/main/Pytorch_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
